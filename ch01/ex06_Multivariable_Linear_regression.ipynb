# %% [markdown]
# #### Multivariate Linear Regression
# - Simple Linear Regression
#  - 1 of hours studied
#  - Test score is 2
# $$H(x) = W(x) + b $$
# - Multivariate Linear Regression
#     - 73, 80, 75 Quiz Score
#     - Final Score Prediction
# $$ H(x) = W_1X_1 + W_2X_2 + W_3X_3 +b$$
#
#     - Cost Function
# $$cost(w) = \frac{1}{m}\sum_\text{i=1}^m = (H(x^\text{(i)}) - y^ \text{(i)})^2$$
#
#     - Gradient descent
# $$\nabla{W} = \frac{\partial{cost}}{\partial{W}} = \frac{2}{w}\sum_{\text{i=1}}^m(Wx^\text{(i)} -y^{\text{(i)}})x^\text{(i)} $$
#
# |Quiz(x1)|Quiz(x2)|Quiz(x3)|Final(y)|
# |:---:|:----:|:----:|:------:|
# |73|80|75|152|
# |93|88|93|185|
# |89|91|80|180|
# |96|98|100|196|
# |73|66|70|142|
#
#
#
# - Native Data Representation
# - Matrix Data Representation
# - Multivariate Linear Regression

# %%
import numpy as np
import matplotlib.pyplot as plt 

import torch 
import torch.nn as nn 
import torch.nn.functional as F
import torch.optim as optim

# %%
# create dummy data 
x_train = torch.FloatTensor([[73, 80, 75],
                             [93, 88, 93], 
                             [89, 91, 80],
                             [96, 98, 100], 
                             [73, 66, 70]])
y_train = torch.FloatTensor([[152], [185], [180],[196], [142]])

print(x_train.shape)
print(y_train.shape)
print(x_train[:, 0])
# hypothesis  
w = torch.zeros((3, 1), requires_grad=True)
b = torch.zeros(1, requires_grad=True)
# hypothesis = x_train[0, :] * w1  + x_train[1, :] * w2 + x_train[2, :] + w3

nb_epochs = 20 
optimizer = optim.SGD([w, b], lr=1e-5)

for epoch in range(nb_epochs +1):

    hypothesis = x_train.matmul(w) + b
    cost = torch.mean((hypothesis-y_train) ** 2)

    optimizer.zero_grad()
    cost.backward()
    optimizer.step()

    print("Epoch {:4d}/{} hypothesis{} cost:{:.6f}.".format(epoch, nb_epochs, hypothesis.squeeze().detach(), cost.item()))
# Out:
# torch.Size([5, 3])
# torch.Size([5, 1])
# tensor([73., 93., 89., 96., 73.])
# Epoch    0/20 hypothesistensor([0., 0., 0., 0., 0.]) cost:29661.800781.
# Epoch    1/20 hypothesistensor([66.7178, 80.1701, 76.1025, 86.0194, 61.1565]) cost:9537.694336.
# Epoch    2/20 hypothesistensor([104.5421, 125.6208, 119.2478, 134.7862,  95.8280]) cost:3069.590088.
# Epoch    3/20 hypothesistensor([125.9858, 151.3882, 143.7087, 162.4333, 115.4844]) cost:990.670288.
# Epoch    4/20 hypothesistensor([138.1429, 165.9963, 157.5768, 178.1071, 126.6283]) cost:322.481873.
# Epoch    5/20 hypothesistensor([145.0350, 174.2780, 165.4395, 186.9928, 132.9461]) cost:107.717064.
# Epoch    6/20 hypothesistensor([148.9423, 178.9730, 169.8976, 192.0301, 136.5279]) cost:38.687496.
# Epoch    7/20 hypothesistensor([151.1574, 181.6346, 172.4254, 194.8856, 138.5585]) cost:16.499043.
# Epoch    8/20 hypothesistensor([152.4131, 183.1435, 173.8590, 196.5043, 139.7097]) cost:9.365656.
# ...

# %%
class LinearRegression_Model(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear == nn.Linear(1, 1)
    
    def forward(self, x):
        return self.linear(x)

# %%
class MultivariateLinearRegression_Model(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear = nn.Linear(3, 1)

    def forward(self, x):
        return self.linear(x)

# %%
x_train = torch.FloatTensor([[73, 80, 75],
                             [93, 88, 93],
                             [89, 91, 90],
                             [96, 98, 100],
                             [73, 66, 70]])
y_train = torch.FloatTensor([[152], [185], [180], [196], [142]])

model = MultivariateLinearRegression_Model()

optimizer = optim.SGD(model.parameters(), lr=1e-5)

nb_epochs = 20
for epoch in range(nb_epochs+1):
    
    prediction = model(x_train)
    
    cost = F.mse_loss(prediction, y_train)
    
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()
    
    print('Epoch {:4d}/{} Cost: {:.6f}'.format(
        epoch, nb_epochs, cost.item()
    ))
# Out:
# Epoch    0/20 Cost: 16462.583984
# Epoch    1/20 Cost: 5161.219727
# Epoch    2/20 Cost: 1618.841064
# Epoch    3/20 Cost: 508.493347
# Epoch    4/20 Cost: 160.458313
# Epoch    5/20 Cost: 51.366955
# Epoch    6/20 Cost: 17.172338
# Epoch    7/20 Cost: 6.453588
# Epoch    8/20 Cost: 3.093363
# Epoch    9/20 Cost: 2.039602
# Epoch   10/20 Cost: 1.708853
# Epoch   11/20 Cost: 1.604713
# Epoch   12/20 Cost: 1.571574
# Epoch   13/20 Cost: 1.560735
# Epoch   14/20 Cost: 1.556845
# Epoch   15/20 Cost: 1.555145
# Epoch   16/20 Cost: 1.554153
# Epoch   17/20 Cost: 1.553370
# Epoch   18/20 Cost: 1.552643
# Epoch   19/20 Cost: 1.551936
# Epoch   20/20 Cost: 1.551240
